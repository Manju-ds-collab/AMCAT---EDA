# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df=pd.read_excel('/content/drive/MyDrive/PG/Internship Task/data.xlsx')
df
# Out:
#      Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0         train  203097   420000 2012-06-01              present
# 1         train  579905   500000 2013-09-01              present
# 2         train  810601   325000 2014-06-01              present
# 3         train  267447  1100000 2011-07-01              present
# 4         train  343523   200000 2014-03-01  2015-03-01 00:00:00
# ...         ...     ...      ...        ...                  ...
# 3993      train   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994      train  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995      train  355888   320000 2013-07-01              present
# 3996      train  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997      train  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# ...

# %%
df.drop('Unnamed: 0', axis=1,inplace = True)

# %%
df
# Out:
#           ID   Salary        DOJ                  DOL  \
# 0     203097   420000 2012-06-01              present
# 1     579905   500000 2013-09-01              present
# 2     810601   325000 2014-06-01              present
# 3     267447  1100000 2011-07-01              present
# 4     343523   200000 2014-03-01  2015-03-01 00:00:00
# ...      ...      ...        ...                  ...
# 3993   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995  355888   320000 2013-07-01              present
# 3996  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# 1               assistant manager            Indore      m 1989-10-04
# 2                systems engineer           Chennai      f 1992-08-03
# ...

# %%
df.head()
# Out:
#        ID   Salary        DOJ                  DOL               Designation  \
# 0  203097   420000 2012-06-01              present   senior quality engineer
# 1  579905   500000 2013-09-01              present         assistant manager
# 2  810601   325000 2014-06-01              present          systems engineer
# 3  267447  1100000 2011-07-01              present  senior software engineer
# 4  343523   200000 2014-03-01  2015-03-01 00:00:00                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
# 3    Gurgaon      m 1989-12-05          85.6                            cbse
# 4    Manesar      m 1991-02-27          78.0                            cbse
#
# ...

# %%
df.shape
# Out:
# (3998, 38)

# %%
df.describe()
# Out:
#                  ID        Salary                            DOJ  \
# count  3.998000e+03  3.998000e+03                           3998
# mean   6.637945e+05  3.076998e+05  2013-07-02 11:04:10.325162496
# min    1.124400e+04  3.500000e+04            1991-06-01 00:00:00
# 25%    3.342842e+05  1.800000e+05            2012-10-01 00:00:00
# 50%    6.396000e+05  3.000000e+05            2013-11-01 00:00:00
# 75%    9.904800e+05  3.700000e+05            2014-07-01 00:00:00
# max    1.298275e+06  4.000000e+06            2015-12-01 00:00:00
# std    3.632182e+05  2.127375e+05                            NaN
#
#                                  DOB  10percentage  12graduation  \
# count                           3998   3998.000000   3998.000000
# mean   1990-12-06 06:01:15.637819008     77.925443   2008.087544
# min              1977-10-30 00:00:00     43.000000   1995.000000
# 25%              1989-11-16 06:00:00     71.680000   2007.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %% [markdown]
# #### Univariate Analysis - Numerical Columns
# Visual and Non-Visual

# %%
## visualisation of continuous numerical variable
def continous_vis_analysis(data,col):
   fig, axes = plt.subplots(1,3,figsize=(10,4),layout='constrained')
   fig.suptitle('Continous Data Distribution')

   axes[0].set_title('Histogram')
   sns.histplot(data[col],ax=axes[0])

   axes[1].set_title('KDE plot')
   sns.kdeplot(data[col],ax=axes[1])

   axes[2].set_title('Box plot')
   sns.boxplot(data[col],ax=axes[2])

   fig.show()

## Non visual analaysis of continuous numerical data
def continous_non_vis_analysis(data,col):
  print(f'Non-Visual Analysis {col}')
  series=data[col]
  print(series.agg(['count','min','max','mean','median','var','std','skew','kurt']).round(2))
  print()

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df['Salary']=df['Salary'].astype(float)

# %%
continous_vis_analysis(df,'Salary')
continous_non_vis_analysis(df,'Salary')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis Salary
# count     3.998000e+03
# min       3.500000e+04
# max       4.000000e+06
# mean      3.076998e+05
# median    3.000000e+05
# var       4.525724e+10
# std       2.127375e+05
# skew      6.450000e+00
# kurt      8.093000e+01
# Name: Salary, dtype: float64

# %% [markdown]
# Salary Column:
# 1. KDE plot shows data is highly rightskewed.
# 2. Kurtosis value depicts the graph is lyptokurtic
# 3. Box plot shows there are so many outliers in the data

# %%
continous_vis_analysis(df,'10percentage')
continous_non_vis_analysis(df,'10percentage')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis 10percentage
# count     3998.00
# min         43.00
# max         97.76
# mean        77.93
# median      79.15
# var         97.03
# std          9.85
# skew        -0.59
# kurt        -0.11
# Name: 10percentage, dtype: float64

# %% [markdown]
# 10percentage Column:
# 1. KDE plot shows data is sligtly left skewed
# 2. Histogram shows the marks obtained by students are mostly in between 70 to 100
# 3. Box plot depicts some outliers below 50

# %%
pd.set_option('display.max_columns', None)

# %%
continous_vis_analysis(df,'12percentage')
continous_non_vis_analysis(df,'12percentage')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis 12percentage
# count     3998.00
# min         40.00
# max         98.70
# mean        74.47
# median      74.40
# var        121.00
# std         11.00
# skew        -0.03
# kurt        -0.63
# Name: 12percentage, dtype: float64

# %% [markdown]
# 12percentage:
# 1. From KDE plot data looks like normally distrubuted
# 2. From box plot there are very less outliers

# %%
df['CollegeTier'] = df['CollegeTier'].astype(object)

# %%
continous_vis_analysis(df,'collegeGPA')
continous_non_vis_analysis(df,'collegeGPA')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis collegeGPA
# count     3998.00
# min          6.45
# max         99.93
# mean        71.49
# median      71.72
# var         66.71
# std          8.17
# skew        -1.25
# kurt        10.23
# Name: collegeGPA, dtype: float64

# %% [markdown]
# collegeGPA:
# 1. Histogram shows the most of the students got CGPA between 60 to 80
# 2. Kde plot shows data is slightly left skewed
# 3. Box plot shows outliers below 20

# %%
df['CollegeCityTier'] = df['CollegeCityTier'].astype(object)

# %%
continous_vis_analysis(df,'English')
continous_non_vis_analysis(df,'English')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis English
# count      3998.00
# min         180.00
# max         875.00
# mean        501.65
# median      500.00
# var       11012.41
# std         104.94
# skew          0.19
# kurt         -0.25
# Name: English, dtype: float64

# %% [markdown]
# English:
# 1. English scores kde plot shows a normal distribution
# 2. Box plot shows few outliers

# %%
continous_vis_analysis(df,'Logical')
continous_non_vis_analysis(df,'Logical')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis Logical
# count     3998.00
# min        195.00
# max        795.00
# mean       501.60
# median     505.00
# var       7531.34
# std         86.78
# skew        -0.22
# kurt        -0.22
# Name: Logical, dtype: float64

# %% [markdown]
# Logical:
# 1. Logical scores kde plot shows a normal distributions
# 2. Box plot depicts there are few outliers in the data

# %%
continous_vis_analysis(df,'Quant')
continous_non_vis_analysis(df,'Quant')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis Quant
# count      3998.00
# min         120.00
# max         900.00
# mean        513.38
# median      515.00
# var       14957.86
# std         122.30
# skew         -0.02
# kurt         -0.10
# Name: Quant, dtype: float64

# %% [markdown]
# Quant:
# 1. KDE plot shows normal distribution
# 2. Box plot shows some outliers

# %%
# continous_vis_analysis(df,'Domain')
# continous_non_vis_analysis(df,'Domain')

# %%
continous_vis_analysis(df,'ComputerProgramming')
continous_non_vis_analysis(df,'ComputerProgramming')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis ComputerProgramming
# count      3998.00
# min          -1.00
# max         840.00
# mean        353.10
# median      415.00
# var       42170.89
# std         205.36
# skew         -0.78
# kurt         -0.67
# Name: ComputerProgramming, dtype: float64

# %% [markdown]
# ComputerProgramming:
# 1. From histogram most of the scores lie b/w 400 to 600
# 2. KDE plot shows data doesnt follow normal distribution

# %%
continous_vis_analysis(df,'ElectronicsAndSemicon')
continous_non_vis_analysis(df,'ElectronicsAndSemicon')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis ElectronicsAndSemicon
# count      3998.00
# min          -1.00
# max         612.00
# mean         95.33
# median       -1.00
# var       25040.28
# std         158.24
# skew          1.20
# kurt         -0.21
# Name: ElectronicsAndSemicon, dtype: float64

# %% [markdown]
# ElectronicsAndSemicon:
# 1. Most of the students did not score well in ElectronicsAndSemicon.

# %%
continous_vis_analysis(df,'ComputerScience')
continous_non_vis_analysis(df,'ComputerScience')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis ComputerScience
# count      3998.00
# min          -1.00
# max         715.00
# mean         90.74
# median       -1.00
# var       30720.65
# std         175.27
# skew          1.53
# kurt          0.69
# Name: ComputerScience, dtype: float64

# %% [markdown]
# ComputerScience:
# 1. Data is getting effected by outlier -1

# %%
df['ComputerScience'].unique()
# Out:
# array([ -1, 407, 346, 376, 500, 438, 315, 253, 469, 192, 530, 284, 223,
#        561, 684, 592, 623, 653, 130, 715])

# %%
continous_vis_analysis(df,'MechanicalEngg')
continous_non_vis_analysis(df,'MechanicalEngg')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis MechanicalEngg
# count     3998.00
# min         -1.00
# max        623.00
# mean        22.97
# median      -1.00
# var       9628.18
# std         98.12
# skew         4.03
# kurt        15.02
# Name: MechanicalEngg, dtype: float64

# %% [markdown]
# MechanicalEngg:
#
# Data is getting effected by outlier -1

# %%
continous_vis_analysis(df,'ElectricalEngg')
continous_non_vis_analysis(df,'ElectricalEngg')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis ElectricalEngg
# count     3998.00
# min         -1.00
# max        676.00
# mean        16.48
# median      -1.00
# var       7671.24
# std         87.59
# skew         5.06
# kurt        24.88
# Name: ElectricalEngg, dtype: float64

# %% [markdown]
# ElectricalEngg:
# 1. Data is getting effected by outlier -1

# %%
continous_vis_analysis(df,'TelecomEngg')
continous_non_vis_analysis(df,'TelecomEngg')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis TelecomEngg
# count      3998.00
# min          -1.00
# max         548.00
# mean         31.85
# median       -1.00
# var       10994.12
# std         104.85
# skew          3.04
# kurt          7.81
# Name: TelecomEngg, dtype: float64

# %% [markdown]
# TelecomEngg:
# 1. Data is getting effected by outlier -1

# %%
continous_vis_analysis(df,'CivilEngg')
continous_non_vis_analysis(df,'CivilEngg')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis CivilEngg
# count     3998.00
# min         -1.00
# max        516.00
# mean         2.68
# median      -1.00
# var       1343.85
# std         36.66
# skew        10.32
# kurt       109.04
# Name: CivilEngg, dtype: float64

# %% [markdown]
# CivilEngg:
# 1. Data is getting effected by outlier -1

# %%
continous_vis_analysis(df,'conscientiousness')
continous_non_vis_analysis(df,'conscientiousness')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis conscientiousness
# count     3998.00
# min         -4.13
# max          2.00
# mean        -0.04
# median       0.05
# var          1.06
# std          1.03
# skew        -0.53
# kurt         0.12
# Name: conscientiousness, dtype: float64

# %% [markdown]
# conscientiousness:
# 1. Follows a normal distribution

# %%
continous_vis_analysis(df,'agreeableness')
continous_non_vis_analysis(df,'agreeableness')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis agreeableness
# count     3998.00
# min         -5.78
# max          1.90
# mean         0.15
# median       0.21
# var          0.89
# std          0.94
# skew        -1.20
# kurt         3.39
# Name: agreeableness, dtype: float64

# %% [markdown]
# agreeableness:
# 1. Slightly left skewed data
# 2. Few outliers below -1

# %%
continous_vis_analysis(df,'extraversion')
continous_non_vis_analysis(df,'extraversion')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis extraversion
# count     3998.00
# min         -4.60
# max          2.54
# mean         0.00
# median       0.09
# var          0.91
# std          0.95
# skew        -0.52
# kurt         0.64
# Name: extraversion, dtype: float64

# %% [markdown]
# extraversion:
# 1. Follows a normal distribution
# 2. Few outliers below -2

# %%
continous_vis_analysis(df,'nueroticism')
continous_non_vis_analysis(df,'nueroticism')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis nueroticism
# count     3998.00
# min         -2.64
# max          3.35
# mean        -0.17
# median      -0.23
# var          1.02
# std          1.01
# skew         0.17
# kurt        -0.19
# Name: nueroticism, dtype: float64

# %% [markdown]
# nueroticism:
# 1. Follows normal distribution

# %%
continous_vis_analysis(df,'openess_to_experience')
continous_non_vis_analysis(df,'openess_to_experience')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Non-Visual Analysis openess_to_experience
# count     3998.00
# min         -7.38
# max          1.82
# mean        -0.14
# median      -0.09
# var          1.02
# std          1.01
# skew        -1.51
# kurt         5.79
# Name: openess_to_experience, dtype: float64

# %% [markdown]
# openess_to_experience:
# 1. Slightly left skewed data.
# 2. Ouliers are below -2

# %%
int_float_df = df.select_dtypes(include=['int', 'float'])
int_float_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   10percentage           3998 non-null   float64
#  3   12graduation           3998 non-null   int64
#  4   12percentage           3998 non-null   float64
#  5   CollegeID              3998 non-null   int64
#  6   collegeGPA             3998 non-null   float64
#  7   CollegeCityID          3998 non-null   int64
#  8   GraduationYear         3998 non-null   int64
#  9   English                3998 non-null   int64
#  10  Logical                3998 non-null   int64
#  11  Quant                  3998 non-null   int64
#  12  Domain                 3998 non-null   float64
#  13  ComputerProgramming    3998 non-null   int64
# ...

# %% [markdown]
# ### Univariate Analysis - Categorical Columns

# %%
def catg_disc_analysis(data,col):
    print('Value Counts for',col)
    print(data[col].value_counts())

    fig,axes=plt.subplots(1,2,figsize=(20,6),layout='constrained')
    fig.suptitle('Categorical / Discrete Num Data Distributions')

    axes[0].set_title('Bar plot')
    sns.countplot(x=col,data=data,ax=axes[0])

    axes[1].set_title('Pie Chart')
    vc_data=data[col].value_counts()
    axes[1].pie(vc_data,labels=vc_data.index,autopct='%1.1f%%')
    fig.show()

# %%
catg_disc_analysis(df,'Designation')
# Out:
# Value Counts for Designation
# Designation
# software engineer                    539
# software developer                   265
# system engineer                      205
# programmer analyst                   139
# systems engineer                     118
#                                     ...
# cad drafter                            1
# noc engineer                           1
# human resources intern                 1
# senior quality assurance engineer      1
# jr. software developer                 1
# Name: count, Length: 419, dtype: int64

# %%
catg_disc_analysis(df,'JobCity')
# Out:
# Value Counts for JobCity
# JobCity
# Bangalore           627
# -1                  461
# Noida               368
# Hyderabad           335
# Pune                290
#                    ...
# Tirunelvelli          1
# Ernakulam             1
# Nanded                1
# Dharmapuri            1
# Asifabadbanglore      1
# Name: count, Length: 339, dtype: int64

# %%
catg_disc_analysis(df,'Gender')
# Out:
# Value Counts for Gender
# Gender
# m    3041
# f     957
# Name: count, dtype: int64

# %%
catg_disc_analysis(df,'10board')
# Out:
# Value Counts for 10board
# 10board
# cbse                          1395
# state board                   1164
# 0                              350
# icse                           281
# ssc                            122
#                               ...
# hse,orissa                       1
# national public school           1
# nagpur board                     1
# jharkhand academic council       1
# bse,odisha                       1
# Name: count, Length: 275, dtype: int64

# %%
catg_disc_analysis(df,'12board')

# %%
int_float_df = df.select_dtypes(include=['object'])
int_float_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DOL              3998 non-null   object
#  1   Designation      3998 non-null   object
#  2   JobCity          3998 non-null   object
#  3   Gender           3998 non-null   object
#  4   10board          3998 non-null   object
#  5   12board          3998 non-null   object
#  6   CollegeTier      3998 non-null   object
#  7   Degree           3998 non-null   object
#  8   Specialization   3998 non-null   object
#  9   CollegeCityTier  3998 non-null   object
#  10  CollegeState     3998 non-null   object
# dtypes: object(11)
# memory usage: 343.7+ KB

# %% [markdown]
# ## Bivariate Analysis

# %%
df.columns

# %%
int_float_df.info()

# %%
df.shape
# Out:
# (3998, 38)

# %% [markdown]
# ### Numerical Vs Numerical

# %%
sns.scatterplot(data=df,x='Salary',y='collegeGPA')
# Out:
# <Axes: xlabel='Salary', ylabel='collegeGPA'>

# %% [markdown]
# Salary vs collegeGPA:
# 1. Most of the students who got 60 to 90 GPA has got salary between 5lakh to 15lakh
# 2. Few students got salary greater than 20 lakh

# %%
sns.scatterplot(data=df,x='ComputerScience',y='Salary')
# Out:
# <Axes: xlabel='ComputerScience', ylabel='Salary'>

# %% [markdown]
# Salary vs Computer science:
# 1. Salary of Computerscience students is below 20 lakhs

# %%
sns.scatterplot(data=df,x='MechanicalEngg',y='Salary')
# Out:
# <Axes: xlabel='MechanicalEngg', ylabel='Salary'>

# %% [markdown]
# Salary Vs MechanicalEngg:
# 1. Salary for MechanicalEngg is below 15 lakh
#
# ---

# %%
sns.scatterplot(data=df,x='ElectricalEngg',y='Salary')
# Out:
# <Axes: xlabel='ElectricalEngg', ylabel='Salary'>

# %% [markdown]
# Salary vs ElectricalEngg:
# 1. ElectricalEngg salary is below 5lakh

# %%
sns.scatterplot(data=df,x='TelecomEngg',y='Salary')
# Out:
# <Axes: xlabel='TelecomEngg', ylabel='Salary'>

# %% [markdown]
# Salary vs TelecomEngg:
# 1. Most of the Telecom Engg got salary below 10lakhs

# %%
sns.scatterplot(data=df,x='CivilEngg',y='Salary')
# Out:
# <Axes: xlabel='CivilEngg', ylabel='Salary'>

# %% [markdown]
# Salary Vs CivilEngg:
# 1. Most of the CivilEngg got salary below 10 lakh

# %% [markdown]
# ### Numerical vs Categorical

# %%
sns.barplot(data=df,x='Designation',y='Salary')

# %%
sns.barplot(data=df,x='Gender',y='Salary')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# Gender Vs Salary:
# 1. Most of the Men are earning salary more than Female

# %%
plt.figure(figsize = (14,3))
sns.barplot(data=df,x='Specialization',y='Salary')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Salary vs Specialization:
# 1. It shows that polymer Technology people have got salaries upto 7 lakh

# %%
plt.figure(figsize = (30,3))
sns.barplot(data=df,x='Designation',y='Salary')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (30,3))
sns.barplot(data=df,x='JobCity',y='Salary')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Catergorical vs Categorical

# %%
ct1=pd.crosstab(df['Specialization'],df['Gender'])
plt.figure(figsize=(30,15))
ct1.plot(kind='bar', stacked = True)
plt.show()

# %% [markdown]
# Gender vs Specialization:
# 1. Most of the Male and Female candidates are interested in electronics and communication engineering

# %% [markdown]
# Q-1 Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.

# %%
roles = ['programming analyst', 'software engineer', 'hardware engineer', 'associate engineer']
Graduates = df[(df['Designation'].isin(roles)) & (df['Specialization'] == 'computer science & engineering')]
Graduates

# %%
print(Graduates['Salary'].describe())

# %%
within_range = Graduates[(Graduates['Salary'] >= 250000) & (Graduates['Salary'] <= 300000)]
within_range
# Out:
#            ID    Salary        DOJ                  DOL        Designation  \
# 55     989860  250000.0 2014-08-01              present  software engineer
# 320    451903  300000.0 2014-05-01              present  software engineer
# 389   1043845  275000.0 2014-06-01              present  software engineer
# 410   1084021  300000.0 2014-05-01  2015-04-01 00:00:00  software engineer
# 499    845544  300000.0 2014-11-01  2015-05-01 00:00:00  software engineer
# 548    340628  300000.0 2013-05-01  2014-04-01 00:00:00  software engineer
# 603    820700  265000.0 2015-01-01              present  software engineer
# 978   1143459  275000.0 2014-07-01              present  software engineer
# 1003   745903  300000.0 2013-09-01              present  software engineer
# 1181   999212  300000.0 2014-03-01              present  software engineer
# 1224  1062611  275000.0 2014-08-01              present  software engineer
# ...

# %%
within_percentage = (len(within_range) / len(Graduates)) * 100
print(f"Percentage of graduates earning within the claimed range (₹2.5-3 lakhs): {within_percentage:.2f}%")

# %% [markdown]
# 1. Computer Science Engineering students earning 2.5 to 3 lakhs are about 17.02%

# %% [markdown]
# Q-2 Is there a relationship between gender and specialization? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
ct1=pd.crosstab(df['Specialization'],df['Gender'])
plt.figure(figsize = (25,25))
ct1.plot(kind='bar', stacked = True)
plt.show()

# %%
ct1
# Out:
# Gender                                         f    m
# Specialization
# aeronautical engineering                       1    2
# applied electronics and instrumentation        2    7
# automobile/automotive engineering              0    5
# biomedical engineering                         2    0
# biotechnology                                  9    6
# ceramic engineering                            0    1
# chemical engineering                           1    8
# civil engineering                              6   23
# computer and communication engineering         0    1
# computer application                          59  185
# computer engineering                         175  425
# computer networking                            0    1
# computer science                               1    1
# computer science & engineering               183  561
# computer science and technology                2    4
# control and instrumentation engineering        0    1
# ...

# %% [markdown]
# From the above graph we can understand that:
# 1. Based on Gender there is no preference of specialization.
# 2. Maximum number of students opted for electronics and communication engineering,information technology and electronics and electrical engineering, computer engineering, computer science & engineering have attended the AMCAT test.
# 3. Some bias can be seen for students opting mechanical engineering as 191 male and only 10 female students.

# %% [markdown]
# Q-3 : What are designation and Engineering streams with high salary above 15 Lakhs?

# %%
high_salary_df = df[df['Salary']>=1500000]
plt.figure(figsize = (20,10))
sns.barplot(data=high_salary_df,x='Salary',y='Designation',hue='Specialization',orient='h')
plt.xticks(rotation = 90)
plt.show()

# %%
high_salary_df['Specialization'].unique()
# Out:
# array(['computer science & engineering', 'electrical engineering',
#        'computer engineering', 'computer application',
#        'electronics and communication engineering',
#        'electronics and electrical engineering',
#        'electronics & instrumentation eng',
#        'electronics and instrumentation engineering',
#        'information technology'], dtype=object)

# %% [markdown]
# From this data we can get an insight of salaries of students above 15LPA with designation and enggineering stream:
# 1. **Designations**:'application developer', 'field engineer','assistant system engineer', 'software test engineer','senior software engineer', 'operations analyst','software engineer trainee', 'programmer', 'software developer','automation engineer', 'client services associate','java software engineer', 'data scientist', 'salesforce developer','software engineer', 'it technician', 'technical lead'
# 2. **Specialization**: 'computer science & engineering', 'electrical engineering','computer engineering', 'computer application','electronics and communication engineering','electronics and electrical engineering','electronics & instrumentation eng','electronics and instrumentation engineering','information technology'

# %% [markdown]
# Q-4: What are the job locations where the salary is paid above 15LPA?

# %%
high_salary_df = df[df['Salary']>=1500000]
plt.figure(figsize = (15,10))
sns.barplot(data=high_salary_df,x='Salary',y='JobCity',hue='Gender',orient='h')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above graph we understand that,
# 1. Gurgaon and New Delhi stands with highest salary of 35 to 40 LPA with Men Employees
# 2. Most of the Female associates are working in Pune are having high salary package of 35LPA.

# %% [markdown]
# Q-5 Comparing Men and Women, who are earning the high salaries?

# %%
high_salary_df = df[df['Salary']>=1500000]
plt.figure(figsize = (10,5))
sns.barplot(data=high_salary_df,x='Salary',y='Degree',hue='Gender',orient='h')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above comparative graph:
# 1. Most of the female employees earning above 15LPA have completed their M.Tech.
# 2. MCA candidates have got package above 30LPA.

# %% [markdown]
# Q-6 Based on Gender what are the salary packages gained?

# %%
high_salary_df = df[df['Salary']>=1500000]
plt.figure(figsize = (20,8))
sns.barplot(data=high_salary_df,x='Salary',y='Gender',hue='Specialization',orient='h')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above graph:
# 1. Computer Science students have got salaries neart 35LPA with max. number of female employees.
# 2. Computer application, electronics and communication engineering students are placed with salary packages above 30LPA.

# %% [markdown]
# Q-7 What is the relation of CollegeGPA with Salary packages?

# %%
high_salary_df = df[df['Salary']>=1500000]
plt.figure(figsize = (15,10))
sns.barplot(data=high_salary_df,x='Salary',y='collegeGPA',hue='Specialization',orient='h')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above graph:
# 1. Surprisingly students with GPA above 76 have placed in less salary compared to students securing below 75GPA.
# 2. Computer science students with GPA of 75 have got the highest package of 40LPA
